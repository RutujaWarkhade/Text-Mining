# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open("C:\8-text minning\sample_doc.html"),'html.parser')
print(soup)

#it is going to show all the html contents extracted
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title> A sample HTML Page </title>
# </head>
# <body>
# I am staying at <address> Mess on No. 72, Banamali Naskar Lane, Kolkata.</address> <br/>
# <b>Sherlock </b> stays at <address>221B, Baker Street, London, UK.</address> <br/>
# <b>Hamlet</b> said to <b>Horatio</b>, <br/> <q> There are more things in heaven and earth, Horatio, <br/> Than are dreamt of in your philosophy. </q>
# <h1> A table denoting details of students</h1>
# <table>
# <tr>
# <th>name</th>
# <th>qualification</th>
# <th>additional qualification</th>
# <th>other qualification</th>
# </tr>
# <tr>
# <td>Gangaram</td>
# <td>B.Tech</td>
# <td>NA</td>
# <td>NA</td>
# </tr>
# <tr>
# <td>Ganga</td>
# <td>B.A.</td>
# <td>NA</td>
# <td>NA</td>
# </tr>
# <tr>
# <td>Ram</td>
# <td>B.Tech</td>
# <td>M.Tech</td>
# <td>NA</td>
# </tr>
# <tr>
# <td>Ramlal</td>
# <td>B.Music</td>
# <td>NA</td>
# <td>Diploma in Music</td>
# </tr>
# </table>
# </body>
# </html>

# %%
soup.text
#it will show only text
# Out:
# '\n\n\n A sample HTML Page \n\n\nI am staying at  Mess on No. 72, Banamali Naskar Lane, Kolkata. \nSherlock  stays at 221B, Baker Street, London, UK. \nHamlet said to Horatio,   There are more things in heaven and earth, Horatio,  Than are dreamt of in your philosophy. \n A table denoting details of students\n\n\nname\nqualification\nadditional qualification\nother qualification\n\n\nGangaram\nB.Tech\nNA\nNA\n\n\nGanga\nB.A.\nNA\nNA\n\n\nRam\nB.Tech\nM.Tech\nNA\n\n\nRamlal\nB.Music\nNA\nDiploma in Music\n\n\n\n'

# %%
soup.contents
#it is going to show all the html contents extracted
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title> A sample HTML Page </title>
#  </head>
#  <body>
#  I am staying at <address> Mess on No. 72, Banamali Naskar Lane, Kolkata.</address> <br/>
#  <b>Sherlock </b> stays at <address>221B, Baker Street, London, UK.</address> <br/>
#  <b>Hamlet</b> said to <b>Horatio</b>, <br/> <q> There are more things in heaven and earth, Horatio, <br/> Than are dreamt of in your philosophy. </q>
#  <h1> A table denoting details of students</h1>
#  <table>
#  <tr>
#  <th>name</th>
#  <th>qualification</th>
#  <th>additional qualification</th>
#  <th>other qualification</th>
#  </tr>
#  <tr>
#  <td>Gangaram</td>
#  <td>B.Tech</td>
#  <td>NA</td>
#  <td>NA</td>
#  </tr>
#  <tr>
#  <td>Ganga</td>
#  <td>B.A.</td>
#  <td>NA</td>
#  <td>NA</td>
#  </tr>
#  <tr>
#  <td>Ram</td>
#  <td>B.Tech</td>
#  <td>M.Tech</td>
#  <td>NA</td>
#  </tr>
#  <tr>
#  <td>Ramlal</td>
#  <td>B.Music</td>
#  <td>NA</td>
#  <td>Diploma in Music</td>
#  </tr>
#  </table>
#  </body>
# ...

# %%
soup.find('address')
soup.find_all('address')
soup.find_all('q')
soup.find_all('b')
# Out:
# [<b>Sherlock </b>, <b>Hamlet</b>, <b>Horatio</b>]

# %%
table=soup.find('table')
table
# Out:
# <table>
# <tr>
# <th>name</th>
# <th>qualification</th>
# <th>additional qualification</th>
# <th>other qualification</th>
# </tr>
# <tr>
# <td>Gangaram</td>
# <td>B.Tech</td>
# <td>NA</td>
# <td>NA</td>
# </tr>
# <tr>
# <td>Ganga</td>
# <td>B.A.</td>
# <td>NA</td>
# <td>NA</td>
# </tr>
# <tr>
# <td>Ram</td>
# <td>B.Tech</td>
# <td>M.Tech</td>
# <td>NA</td>
# </tr>
# <tr>
# <td>Ramlal</td>
# <td>B.Music</td>
# <td>NA</td>
# <td>Diploma in Music</td>
# </tr>
# </table>

# %%
for row in table.find_all('tr'):
    columns=row.find_all('td')
    print(columns)
    
#it will show all the rows except first row
# Out:
# []
# [<td>Gangaram</td>, <td>B.Tech</td>, <td>NA</td>, <td>NA</td>]
# [<td>Ganga</td>, <td>B.A.</td>, <td>NA</td>, <td>NA</td>]
# [<td>Ram</td>, <td>B.Tech</td>, <td>M.Tech</td>, <td>NA</td>]
# [<td>Ramlal</td>, <td>B.Music</td>, <td>NA</td>, <td>Diploma in Music</td>]

# %%
#now we want to display m.tech which is located in third row
#i need to give [3][2]
table.find_all('tr')[3].find_all('td')[2]
# Out:
# <td>M.Tech</td>

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open("C:\8-text minning\sample_doc.html"),'html.parser')
print(soup)

# %%
from bs4 import BeautifulSoup as bs
import requests
link = "https://sanjivani.org.in/contact-us/"
page = requests.get(link)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<link rel="profile" href="https://gmpg.org/xfn/11">\n\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO Premium plugin v20.4 (Yoast SEO v23.2) - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Contact Us - Sanjivani Group of Institutes</title>\n\t<link rel="canonical" href="https://sanjivani.org.in/contact-us/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Contact Us" />\n\t<meta property="og:description" content="FIND US Tal :Kopargaon, District: Ahmednagar, Maharashtra Pin : 423603 WORKING HOURS Mon-Fri: 8 AM &#8211; 5 PM Sat-Sun: 8 AM &#8211; 2 PM For Appointments +91-9130191301 Email Us contact@sanjivani.org.in" />\n\t<me
# ...

# %%
soup = bs(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO Premium plugin v20.4 (Yoast SEO v23.2) - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Contact Us - Sanjivani Group of Institutes</title>
# <link href="https://sanjivani.org.in/contact-us/" rel="canonical">
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="Contact Us" property="og:title"/>
# <meta content="FIND US Tal :Kopargaon, District: Ahmednagar, Maharashtra Pin : 423603 WORKING HOURS Mon-Fri: 8 AM – 5 PM Sat-Sun: 8 AM – 2 PM For Appointments +91-9130191301 Email Us contact@sanjivani.org.in" property="og:description"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <!-- This site is optimized with the Yoast SEO Premium plugin v20.4 (Yoast SEO v23.2) - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     Contact Us - Sanjivani Group of Institutes
#    </title>
#    <link href="https://sanjivani.org.in/contact-us/" rel="canonical">
#     <meta content="en_US" property="og:locale">
#      <meta content="article" property="og:type"/>
#      <meta content="Contact Us" property="og:title"/>
# ...

# %%
list(soup.prettify())
# Out:
# ['<',
#  '!',
#  'D',
#  'O',
#  'C',
#  'T',
#  'Y',
#  'P',
#  'E',
#  ' ',
#  'h',
#  't',
#  'm',
#  'l',
#  '>',
#  '\n',
#  '<',
#  'h',
#  't',
#  'm',
#  'l',
#  ' ',
#  'l',
#  'a',
#  'n',
#  'g',
#  '=',
#  '"',
#  'e',
#  'n',
#  '-',
#  'U',
#  'S',
#  '"',
#  '>',
#  '\n',
#  ' ',
#  '<',
#  'h',
#  'e',
#  'a',
#  'd',
#  '>',
#  '\n',
#  ' ',
#  ' ',
#  '<',
#  'm',
#  'e',
#  't',
#  'a',
#  ' ',
#  'c',
#  'h',
#  'a',
#  'r',
#  's',
#  'e',
#  't',
#  '=',
#  '"',
#  'u',
#  't',
#  'f',
#  '-',
#  '8',
#  '"',
#  '/',
#  '>',
#  '\n',
#  ' ',
#  ' ',
#  '<',
#  'm',
#  'e',
#  't',
#  'a',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'e',
#  'n',
#  't',
#  '=',
#  '"',
#  'w',
#  'i',
#  'd',
#  't',
#  'h',
#  '=',
#  'd',
#  'e',
#  'v',
#  'i',
#  'c',
#  'e',
#  '-',
#  'w',
#  'i',
#  'd',
#  't',
#  'h',
#  ',',
#  ' ',
#  'i',
#  'n',
#  'i',
#  't',
#  'i',
#  'a',
#  'l',
#  '-',
#  's',
#  'c',
#  'a',
#  'l',
#  'e',
#  '=',
#  '1',
#  '"',
#  ' ',
# ...

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html lang="en-US">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <link href="https://gmpg.org/xfn/11" rel="profile"/>
#  <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#  <!-- This site is optimized with the Yoast SEO Premium plugin v20.4 (Yoast SEO v23.2) - https://yoast.com/wordpress/plugins/seo/ -->
#  <title>Contact Us - Sanjivani Group of Institutes</title>
#  <link href="https://sanjivani.org.in/contact-us/" rel="canonical">
#  <meta content="en_US" property="og:locale">
#  <meta content="article" property="og:type"/>
#  <meta content="Contact Us" property="og:title"/>
#  <meta content="FIND US Tal :Kopargaon, District: Ahmednagar, Maharashtra Pin : 423603 WORKING HOURS Mon-Fri: 8 AM – 5 PM Sat-Sun: 8 AM – 2 PM For Appointments +91-9130191301 Email Us contact@sanjivani.org.in" property="og:description"/>
# ...

# %%
soup.find_all('p')
# Out:
# [<p class="elementor-image-box-description">+91-9130191301</p>,
#  <p class="elementor-image-box-description">contact@sanjivani.org.in</p>,
#  <p class="elementor-image-box-description">Tal :Kopargaon,
#  District: Ahmednagar, Maharashtra Pin : 423603</p>,
#  <p class="elementor-image-box-description">Mon-Fri: 8 AM - 5 PM <br/>
#  Sat-Sun: 8 AM - 2 PM</p>,
#  <p class="elementor-image-box-description">+91-9130191301 <br/>
#  <br/>
#  <br/></p>,
#  <p class="elementor-image-box-description">contact@sanjivani.org.in</p>,
#  <p>Sanjivani Group of Institutes has a place among the top and most-preferred educational institutes in the country. Since its inception in 1983 under the guidance of Honorable Late Shankarraoji G. Kolhe</p>]
